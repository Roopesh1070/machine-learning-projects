# %%
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df=pdr.get_data_yahoo("TSLA")

# %%
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-05-31  778.799988  734.229980  773.840027  758.260010  33971500.0
# 2022-06-01  771.979980  730.919983  755.159973  740.369995  25749300.0
# 2022-06-02  792.630005  726.200012  732.469971  775.000000  31157700.0
# 2022-06-03  743.390015  700.250000  729.679993  703.549988  37348100.0
# 2022-06-06  734.599976  703.049988  733.059998  714.840027  28015600.0
#
#              Adj Close
# Date
# 2022-05-31  758.260010
# 2022-06-01  740.369995
# 2022-06-02  775.000000
# 2022-06-03  703.549988
# 2022-06-06  714.840027

# %%
df["High"].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["High"].plot(xlim=["2020-01-01","2021-09-01"],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["High"].plot(xlim=["2019-01-01","2020-01-01"],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["High"].plot(xlim=["2021-01-01","2022-01-01"],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["High"].plot(xlim=["2020-01-01","2021-09-01"],ylim=[0,900],figsize=(12,4),ls='--')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20',
#                ...
#                '2022-05-23', '2022-05-24', '2022-05-25', '2022-05-26',
#                '2022-05-27', '2022-05-31', '2022-06-01', '2022-06-02',
#                '2022-06-03', '2022-06-06'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index=df.loc['2020-02-01':'2021-09-01'].index
share_open=df.loc['2020-02-01':'2021-09-01']["Open"]

# %%
share_open
# Out:
# Date
# 2020-02-03    134.738007
# 2020-02-04    176.591995
# 2020-02-05    164.651993
# 2020-02-06    139.983994
# 2020-02-07    146.110001
#                  ...
# 2021-08-26    708.309998
# 2021-08-27    705.000000
# 2021-08-30    714.719971
# 2021-08-31    733.000000
# 2021-09-01    734.080017
# Name: Open, Length: 400, dtype: float64

# %%
index1=df.loc['2020-02-01':'2021-09-01'].index
share_close=df.loc['2020-02-01':'2021-09-01']["Close"]

# %%
share_close
# Out:
# Date
# 2020-02-03    156.000000
# 2020-02-04    177.412003
# 2020-02-05    146.940002
# 2020-02-06    149.792007
# 2020-02-07    149.613998
#                  ...
# 2021-08-26    701.159973
# 2021-08-27    711.919983
# 2021-08-30    730.909973
# 2021-08-31    735.719971
# 2021-09-01    734.090027
# Name: Close, Length: 400, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
figure,axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()#preventing overlapping
axis.plot(index,share_open)

# %%
date=datetime(2000,12,21)#with hours and minutes

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 3

# %%
date.year
# Out:
# 2000

# %%
d=datetime.now()

# %%
d.weekday()
# Out:
# 1
